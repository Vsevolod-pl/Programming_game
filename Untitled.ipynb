# %%
from Python_client.run_commands import run_match

# %%
# Out:
# [{'x': 0.0, 'y': 0.0, 'hp': 51.0, 'name': 'bot10'}, {'x': 0.0, 'y': 0.0, 'hp': 51.0, 'name': 'bot20'}, {'x': 0.0, 'y': 0.0, 'hp': 51.0, 'name': 'bot21'}]
# [{'x': 45.0, 'y': 45.0, 'hp': 51.0, 'name': 'bot10'}, {'x': 47.935555, 'y': 72.845695, 'hp': 51.0, 'name': 'bot20'}, {'x': 45.0, 'y': 58.983765, 'hp': 51.0, 'name': 'bot21'}]
# [{'x': 73.2843, 'y': 73.2843, 'hp': 51.0, 'name': 'bot10'}, {'x': 52.129204, 'y': 112.625206, 'hp': 51.0, 'name': 'bot20'}, {'x': 45.0, 'y': 98.93412, 'hp': 51.0, 'name': 'bot21'}]
# [{'x': 104.08066, 'y': 98.81058, 'hp': 51.0, 'name': 'bot10'}, {'x': 56.322853, 'y': 152.40482, 'hp': 46.0, 'name': 'bot20'}, {'x': 45.0, 'y': 138.87901, 'hp': 46.0, 'name': 'bot21'}]
# [{'x': 144.0415, 'y': 100.580505, 'hp': 51.0, 'name': 'bot10'}, {'x': 60.516502, 'y': 192.18448, 'hp': 41.0, 'name': 'bot20'}, {'x': 45.0, 'y': 178.81757, 'hp': 41.0, 'name': 'bot21'}]
# ...
